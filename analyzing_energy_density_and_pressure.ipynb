# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
my_array = np.array(pd.read_csv("1e15_T=2_classical_not_equilibrium_QKESolveMPI_results.csv"))

# %%
p0_array = []
for i in range(len(my_array)):
    p0_array.append(my_array[i][1])

# %%
plt.plot(p0_array, "-o")
