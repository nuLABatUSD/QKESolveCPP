# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(en, po):
    return 1/(np.exp(en+po)+1)

# %%
def f_e(en):
    return 1/(np.exp(en/32)+1)

# %%
def F_LR(p1, e2, e3, p4):
    gl = 0.2233702902434699-0.5
    return f_e(e3)*(1-f_e(e2))*((gl+1)*f(p4,0.01)*(1-f(p1,0.01)) + gl*f(p4,-0.01)*(1-f(p1,-0.01))) - f_e(e2)*(1-f_e(e3))*((gl+1)*(1-f(p4,0.01))*f(p1,0.01)+gl*(1-f(p4,-0.01))*f(p1,-0.01))
    #return ((gl+1)*f(p4,0.01)*(1-f(p1,0.01)) + gl*f(p4,-0.01)*(1-f(p1,-0.01)))
    #return f_e(e2)*(1-f_e(e3))*((gl+1)*(1-f(p4,0.01))*f(p1,0.01)+gl*(1-f(p4,-0.01))*f(p1,-0.01))

# %%
F_LR(1.2, 180.698, 181.798, 0.1)/2
# Out:
# 0.00017979345698398863

# %%
0.00018899241967317715

# %%
print((1-f(1.2, 0.01) + 1-f(1.2,-0.01))/2)
# Out:
# 0.7685200066375724

# %%
def F_RR(p1, e2, e3, p4):
    return f_e(e3) * (1-f_e(e2)) * (f(p4,0.01) * (1-f(p1,0.01)) + f(p4,-0.01) * (1-f(p1,-0.01))) - f_e(e2) * (1- f_e(e3)) * ((1-f(p4,0.01)) * f(p1,0.01)+(1-f(p4,-0.01))*f(p1,-0.01))

# %%
F_RR(1.2, 180.6983444148131, 181.3983444148131, 0.5)/2
# Out:
# 0.00048983689119205

# %%
0.0004898368911920505
